# %% [markdown]
# # Automating Fetching MODIS Terra MOD13QA Dataset & Cloud Masking 🤗

# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Define the destination folder
drive_folder = "/content/drive/My Drive/Sprints Final Project/Dateset"

# Create the folder
os.makedirs(drive_folder, exist_ok=True)

print(f"Files will be saved to: {drive_folder}")
# Out:
# Files will be saved to: /content/drive/My Drive/Sprints Final Project/Dateset

# %% [markdown]
# # Mirror‑download NASA LAADS order  into your Drive folder,
# # skipping HTML listings and temp files, flattening the path, and
# # authenticating with your Bearer token.

# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 \
"https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348020/" \
--header "Authorization: Bearer eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6IjNhc3NpMTJ4IiwiZXhwIjoxNzQ4MzQ5NTA4LCJpYXQiOjE3NDMxNjU1MDgsImlzcyI6Imh0dHBzOi8vdXJzLmVhcnRoZGF0YS5uYXNhLmdvdiIsImlkZW50aXR5X3Byb3ZpZGVyIjoiZWRsX29wcyIsImFjciI6ImVkbCIsImFzc3VyYW5jZV9sZXZlbCI6M30.wqkvUwaIUaYXGIm8p0t526l6-Y4EA8PGe8YqnjRUQCfz8bvI_bZOzHmygOVriyRdt8MzZcbjUUpUITBANrsMjyruV8z9oO-S2aMb7gDpQExjJddcCNky1bpPQxBzL2C2EJfMr83mlVK3HYGw_fWkl-9ivrew2pQ-Lp_q1inbXssi4ew1a9p-KK6OH8miUomrWygjK2WD75Av8lJCeQ0LNN_9rJ_H8qv14-wNv0xO-50e9WgXvqkHYxxYs2lYhy3oYflOHQ-cZbUuarl-jP-MyCkapSxN_GtbGY1SXEfMrmr8OTlogNcQCfn2QNC5m-zQUywKGyc2TBvW0VyhERIpdA" \
-P "/content/drive/My Drive/Sprints Final Project/Dataset/"
# Out:
# --2025-03-28 12:46:48--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348020/
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54337 (53K) [text/html]
# Saving to: ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’
#
# index.html.tmp      100%[===================>]  53.06K  --.-KB/s    in 0.04s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-03-28 12:46:49 (1.22 MB/s) - ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’ saved [54337/54337]
#
# Removing /content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp since it should be rejected.
#
# --2025-03-28 12:46:49--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348020/checksums_502348020
# ...

# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 \
"https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348034/" \
--header "Authorization: Bearer eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6IjNhc3NpMTJ4IiwiZXhwIjoxNzQ4MzQ5NTA4LCJpYXQiOjE3NDMxNjU1MDgsImlzcyI6Imh0dHBzOi8vdXJzLmVhcnRoZGF0YS5uYXNhLmdvdiIsImlkZW50aXR5X3Byb3ZpZGVyIjoiZWRsX29wcyIsImFjciI6ImVkbCIsImFzc3VyYW5jZV9sZXZlbCI6M30.wqkvUwaIUaYXGIm8p0t526l6-Y4EA8PGe8YqnjRUQCfz8bvI_bZOzHmygOVriyRdt8MzZcbjUUpUITBANrsMjyruV8z9oO-S2aMb7gDpQExjJddcCNky1bpPQxBzL2C2EJfMr83mlVK3HYGw_fWkl-9ivrew2pQ-Lp_q1inbXssi4ew1a9p-KK6OH8miUomrWygjK2WD75Av8lJCeQ0LNN_9rJ_H8qv14-wNv0xO-50e9WgXvqkHYxxYs2lYhy3oYflOHQ-cZbUuarl-jP-MyCkapSxN_GtbGY1SXEfMrmr8OTlogNcQCfn2QNC5m-zQUywKGyc2TBvW0VyhERIpdA" \
-P "/content/drive/My Drive/Sprints Final Project/Dataset/"
# Out:
# --2025-03-28 12:59:59--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348034/
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54337 (53K) [text/html]
# Saving to: ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’
#
# index.html.tmp      100%[===================>]  53.06K  --.-KB/s    in 0.04s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-03-28 13:00:00 (1.25 MB/s) - ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’ saved [54337/54337]
#
# Removing /content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp since it should be rejected.
#
# --2025-03-28 13:00:00--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348034/checksums_502348034
# ...

# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 \
"https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348049/" \
--header "Authorization: Bearer eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6IjNhc3NpMTJ4IiwiZXhwIjoxNzQ4MzQ5NTA4LCJpYXQiOjE3NDMxNjU1MDgsImlzcyI6Imh0dHBzOi8vdXJzLmVhcnRoZGF0YS5uYXNhLmdvdiIsImlkZW50aXR5X3Byb3ZpZGVyIjoiZWRsX29wcyIsImFjciI6ImVkbCIsImFzc3VyYW5jZV9sZXZlbCI6M30.wqkvUwaIUaYXGIm8p0t526l6-Y4EA8PGe8YqnjRUQCfz8bvI_bZOzHmygOVriyRdt8MzZcbjUUpUITBANrsMjyruV8z9oO-S2aMb7gDpQExjJddcCNky1bpPQxBzL2C2EJfMr83mlVK3HYGw_fWkl-9ivrew2pQ-Lp_q1inbXssi4ew1a9p-KK6OH8miUomrWygjK2WD75Av8lJCeQ0LNN_9rJ_H8qv14-wNv0xO-50e9WgXvqkHYxxYs2lYhy3oYflOHQ-cZbUuarl-jP-MyCkapSxN_GtbGY1SXEfMrmr8OTlogNcQCfn2QNC5m-zQUywKGyc2TBvW0VyhERIpdA" \
-P "/content/drive/My Drive/Sprints Final Project/Dataset/"
# Out:
# --2025-03-28 13:11:01--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348049/
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54337 (53K) [text/html]
# Saving to: ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’
#
# index.html.tmp      100%[===================>]  53.06K  --.-KB/s    in 0.04s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-03-28 13:11:02 (1.32 MB/s) - ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’ saved [54337/54337]
#
# Removing /content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp since it should be rejected.
#
# --2025-03-28 13:11:02--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348049/checksums_502348049
# ...

# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 \
"https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348055/" \
--header "Authorization: Bearer eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6IjNhc3NpMTJ4IiwiZXhwIjoxNzQ4MzQ5NTA4LCJpYXQiOjE3NDMxNjU1MDgsImlzcyI6Imh0dHBzOi8vdXJzLmVhcnRoZGF0YS5uYXNhLmdvdiIsImlkZW50aXR5X3Byb3ZpZGVyIjoiZWRsX29wcyIsImFjciI6ImVkbCIsImFzc3VyYW5jZV9sZXZlbCI6M30.wqkvUwaIUaYXGIm8p0t526l6-Y4EA8PGe8YqnjRUQCfz8bvI_bZOzHmygOVriyRdt8MzZcbjUUpUITBANrsMjyruV8z9oO-S2aMb7gDpQExjJddcCNky1bpPQxBzL2C2EJfMr83mlVK3HYGw_fWkl-9ivrew2pQ-Lp_q1inbXssi4ew1a9p-KK6OH8miUomrWygjK2WD75Av8lJCeQ0LNN_9rJ_H8qv14-wNv0xO-50e9WgXvqkHYxxYs2lYhy3oYflOHQ-cZbUuarl-jP-MyCkapSxN_GtbGY1SXEfMrmr8OTlogNcQCfn2QNC5m-zQUywKGyc2TBvW0VyhERIpdA" \
-P "/content/drive/My Drive/Sprints Final Project/Dataset/"
# Out:
# --2025-03-28 13:18:40--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348055/
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34519 (34K) [text/html]
# Saving to: ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’
#
# index.html.tmp      100%[===================>]  33.71K  --.-KB/s    in 0.005s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-03-28 13:18:41 (6.44 MB/s) - ‘/content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp’ saved [34519/34519]
#
# Removing /content/drive/My Drive/Sprints Final Project/Dataset/index.html.tmp since it should be rejected.
#
# --2025-03-28 13:18:41--  https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/502348055/checksums_502348055
# ...

# %% [markdown]
# # find_qa_dataset: Scans dataset names for QA/quality keywords
#
# extract_cloud_mask:
#
#     Opens each HDF, selects the QA layer,
#
#     Converts it into a binary cloud mask (cloud vs. clear),
#
#     Writes out a new HDF containing only that mask.
#
# Loop at the bottom: Processes every .hdf in Drive folder

# %%
from pyhdf.SD import SD, SDC
import numpy as np

def find_qa_dataset(hdf):
    """Try to find a QA-like dataset name"""
    possible_keywords = ['QA', 'quality', 'QC', 'reliability', 'Summary']
    for name in hdf.datasets().keys():
        lname = name.lower()
        if any(keyword in lname for keyword in possible_keywords):
            return name
    return None

def extract_cloud_mask(hdf_path, save_dir):
    """Extract cloud mask and save to a new HDF file"""
    hdf = SD(hdf_path, SDC.READ)

    qa_name = find_qa_dataset(hdf)
    if qa_name is None:
        print(f"No QA-related dataset found in {os.path.basename(hdf_path)}")
        return

    print(f" Using QA dataset: {qa_name}")
    qa_data = hdf.select(qa_name).get()

    # Example logic for MODIS QA: treat 0 as clear, others as cloudy
    cloud_mask = (qa_data != 0).astype(np.uint8)  # 1 = cloud, 0 = clear

    # Save cloud mask to new HDF
    new_filename = os.path.basename(hdf_path).replace('.hdf', '_cloudmask.hdf')
    new_hdf_path = os.path.join(save_dir, new_filename)

    new_hdf = SD(new_hdf_path, SDC.WRITE | SDC.CREATE)
    sds = new_hdf.create('CLOUD_MASK', SDC.UINT8, cloud_mask.shape)
    sds[:] = cloud_mask
    sds.endaccess()
    new_hdf.end()

# Folder containing MODIS .hdf files
data_folder = "/content/drive/My Drive/Sprints Final Project/Dateset"

#  Process all files
for filename in os.listdir(data_folder):
    if filename.endswith(".hdf"):
        file_path = os.path.join(data_folder, filename)
        extract_cloud_mask(file_path, data_folder)
# Out:
# 📦 Using QA dataset: 250m 16 days VI Quality
